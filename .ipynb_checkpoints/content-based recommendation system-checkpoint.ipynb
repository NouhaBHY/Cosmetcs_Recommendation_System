# %%
import pandas as pd
import numpy as np
from sklearn.manifold import TSNE

df = pd.read_csv('datasets/cosmetics.csv')

#display(df.sample(5))
#df.Label.value_counts()
# Out:
#             Label               Brand  \
# 235   Moisturizer        BAREMINERALS
# 698     Treatment               FOREO
# 848     Face Mask  SEPHORA COLLECTION
# 1358  Sun protect  KIEHL'S SINCE 1851
# 1359  Sun protect               COOLA
#
#                                                    Name  Price  Rank  \
# 235   Prime Time BB Tinted Primer Broad Spectrum SP...     27   4.1
# 698                 Espada Acne-Clearing Blue Light Pen    149   3.9
# 848                              Experiential Masks Set     18   5.0
# 1358  Powerful Wrinkle Reducing Cream Sunscreen Broa...     74   3.5
# 1359               Mineral Face SPF 30 - Cucumber Matte     36   4.4
#
#                                             Ingredients  Combination  Dry  \
# 235                                             No Info            0    0
# 698                            Visit the Foreo boutique            1    1
# 848   The Charcoal Mask: Water, Glycerin, Hydroxyeth...            1    1
# 1358  Water Glycerin, Cetearyl Alcohol, Isohexadecan...            1    1
# 1359  Aluminum Hydroxide, Butyrospermum Parkii (Orga...            1    0
#
#       Normal  Oily  Sensitive
# 235        0     0          0
# 698        1     1          1
# 848        1     1          0
# 1358       1     1          1
# 1359       1     1          1
# Moisturizer    298
# Cleanser       281
# Face Mask      266
# Treatment      248
# Eye cream      209
# Sun protect    170
# Name: Label, dtype: int64

# %%
moisturizers = df[df['Label'] == 'Moisturizer']
moisturizers_dry = moisturizers[moisturizers['Dry'] == 1]
moisturizers_dry = moisturizers_dry.reset_index(drop = True)

# %%
ingredient_idx = {}
corpus = []
idx = 0

for i in range(len(moisturizers_dry)):
    ingredients = moisturizers_dry['Ingredient'][i]
    ingredients_lower = ingredients.lower()
    tokens = ingredients_lower.split(', ')
    corpus.append(tokens)
    for ingredient in tokens:
        if ingredient not in ingredient_idx:
            ingredient_idx[ingredient] = idx
            idx += 1
            
print("The index  for decyl oleate is", ingredient_idx['decyl oleate'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6206/3163675980.py in <module>
#       3 idx = 0
#       4
# ----> 5 for i in range(len(moisturizers_dry)):
#       6     ingredients = moisturizers_dry['Ingredient'][i]
#       7     ingredients_lower = ingredients.lower()
#
# NameError: name 'moisturizers_dry' is not defined
